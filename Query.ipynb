# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\Deepak kumar\Desktop\DA, ML_by_Atma_sir\Data_for_DA\framingham.csv')

# %%
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df.query('male==1')
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 8        1   52        1.0              0         0.0     0.0
# 9        1   43        1.0              1        30.0     0.0
# 12       1   46        1.0              1        15.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4231     1   58        3.0              0         0.0     0.0
# 4232     1   68        1.0              0         0.0     0.0
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df.head(2)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
#
#    TenYearCHD
# 0           0
# 1           0

# %%
df.query('currentSmoker==1')
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# 7        0   45        2.0              1        20.0     0.0
# 9        1   43        1.0              1        30.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 2                   0             0         0    245.0  127.5   80.0  25.34
# ...

# %%
df.query('age>60 and currentSmoker==1')
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 3        0   61        3.0              1        30.0     0.0
# 33       1   61        NaN              1         5.0     0.0
# 48       0   63        2.0              1        40.0     0.0
# 50       0   63        1.0              1         3.0     0.0
# 87       0   61        2.0              1         1.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4122     1   69        NaN              1        23.0     0.0
# 4138     1   67        NaN              1        25.0     0.0
# 4163     1   65        4.0              1         6.0     0.0
# 4194     1   65        1.0              1        20.0     1.0
# 4203     1   63        1.0              1        10.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 3                   0             1         0    225.0  150.0   95.0  28.58
# ...

# %%
df.query('age>60 and currentSmoker==1 and education==1')
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 50       0   63        1.0              1         3.0     0.0
# 175      1   62        1.0              1        20.0     0.0
# 177      0   61        1.0              1        20.0     0.0
# 241      1   65        1.0              1        15.0     0.0
# 311      1   62        1.0              1        20.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4079     1   62        1.0              1         7.0     0.0
# 4094     1   64        1.0              1         5.0     0.0
# 4100     1   69        1.0              1         1.0     0.0
# 4194     1   65        1.0              1        20.0     1.0
# 4203     1   63        1.0              1        10.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 50                  0             1         0    267.0  156.5   92.5  27.10
# ...
