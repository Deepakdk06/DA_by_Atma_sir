# %%
import pandas as pd

# %%
df=pd.read_csv(r"E:\DA_Data\framingham.csv")

# %%
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
def f2(x):
    if(x>50):
        return "sc"
    else:
        return "y"

# %%
df["age_updated"]=df["age"].apply(lambda x:f2(x))

# %%
df.head(10)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
# 5     0   43        2.0              0         0.0     0.0                0
# 6     0   63        1.0              0         0.0     0.0                0
# 7     0   45        2.0              1        20.0     0.0                0
# 8     1   52        1.0              0         0.0     0.0                0
# 9     1   43        1.0              1        30.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# ...

# %%
def f3(x):
    if(x==0):
        return "nhi pita"
    else:
        return "Piakkad"

# %%
df["currentSmoker"]=df["currentSmoker"].apply(lambda x:f3(x))

# %%
df
# Out:
#       male  age  education currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0        1   39        4.0      nhi pita         0.0     0.0                0
# 1        0   46        2.0      nhi pita         0.0     0.0                0
# 2        1   48        1.0       Piakkad        20.0     0.0                0
# 3        0   61        3.0       Piakkad        30.0     0.0                0
# 4        0   46        3.0       Piakkad        23.0     0.0                0
# ...    ...  ...        ...           ...         ...     ...              ...
# 4235     0   48        2.0       Piakkad        20.0     NaN                0
# 4236     0   44        1.0       Piakkad        15.0     0.0                0
# 4237     0   52        2.0      nhi pita         0.0     0.0                0
# 4238     1   40        3.0      nhi pita         0.0     0.0                0
# 4239     0   39        3.0       Piakkad        30.0     0.0                0
#
# ...

# %%
def f3(x):
    if(x==0):
        return "sc"
    else:
        return "y"

# %% [markdown]
# # select_dtypes

# %%
df.dtypes
# Out:
# male                 int64
# age                  int64
# education          float64
# currentSmoker       object
# cigsPerDay         float64
# BPMeds             float64
# prevalentStroke      int64
# prevalentHyp         int64
# diabetes             int64
# totChol            float64
# sysBP              float64
# diaBP              float64
# BMI                float64
# heartRate          float64
# glucose            float64
# TenYearCHD           int64
# age_updated         object
# dtype: object

# %%
num_index=df.select_dtypes(include=["int64","object"]).columns

# %%
num_index
# Out:
# Index(['male', 'age', 'currentSmoker', 'prevalentStroke', 'prevalentHyp',
#        'diabetes', 'TenYearCHD', 'age_updated'],
#       dtype='object')

# %%
subset=df[num_index]

# %%
subset
# Out:
#       male  age currentSmoker  prevalentStroke  prevalentHyp  diabetes  \
# 0        1   39      nhi pita                0             0         0
# 1        0   46      nhi pita                0             0         0
# 2        1   48       Piakkad                0             0         0
# 3        0   61       Piakkad                0             1         0
# 4        0   46       Piakkad                0             0         0
# ...    ...  ...           ...              ...           ...       ...
# 4235     0   48       Piakkad                0             0         0
# 4236     0   44       Piakkad                0             0         0
# 4237     0   52      nhi pita                0             0         0
# 4238     1   40      nhi pita                0             1         0
# 4239     0   39       Piakkad                0             0         0
#
#       TenYearCHD age_updated
# 0              0           y
# 1              0           y
# ...

# %%
df.query("age>39")
# Out:
#       male  age  education currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 1        0   46        2.0      nhi pita         0.0     0.0                0
# 2        1   48        1.0       Piakkad        20.0     0.0                0
# 3        0   61        3.0       Piakkad        30.0     0.0                0
# 4        0   46        3.0       Piakkad        23.0     0.0                0
# 5        0   43        2.0      nhi pita         0.0     0.0                0
# ...    ...  ...        ...           ...         ...     ...              ...
# 4234     1   51        3.0       Piakkad        43.0     0.0                0
# 4235     0   48        2.0       Piakkad        20.0     NaN                0
# 4236     0   44        1.0       Piakkad        15.0     0.0                0
# 4237     0   52        2.0      nhi pita         0.0     0.0                0
# 4238     1   40        3.0      nhi pita         0.0     0.0                0
#
# ...
